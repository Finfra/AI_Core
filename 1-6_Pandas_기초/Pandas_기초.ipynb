# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/gdrive')

# %%
# !cat '/gdrive/My Drive/AI_Core/_data/iris.csv'

# %%
df = pd.read_csv('/gdrive/My Drive/AI_Core/_data/iris.csv', sep = ',')
df

# %%
dir(df)

# %%
df.head()

# %%
df.columns

# %%
df6=df['Species']

# %%
df6.__class__

# %%
print(df6[0],df6[149])

# %%
for r in df6:
  print(r)
